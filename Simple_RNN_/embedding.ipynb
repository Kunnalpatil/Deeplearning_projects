# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good',]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
### Define Vocabulary size
voc_size = 10000

# %%
## One Hot Representaiton
one_hot_repr = [one_hot(words,voc_size) for words in sent]
one_hot_repr
# Out:
# [[3198, 2926, 4068, 1627],
#  [3198, 2926, 4068, 2948],
#  [3198, 949, 4068, 7591],
#  [9576, 775, 2695, 8988, 53],
#  [9576, 775, 2695, 8988, 3060],
#  [7331, 3198, 2451, 4068, 4999],
#  [4071, 2633, 1254, 8988]]

# %%
## word Embedding Representation

from tensorflow.keras.layers import Embedding, Dense
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length = 8
embeded_docs = pad_sequences(one_hot_repr,padding='pre',maxlen = sent_length)
embeded_docs
# Out:
# array([[   0,    0,    0,    0, 3198, 2926, 4068, 1627],
#        [   0,    0,    0,    0, 3198, 2926, 4068, 2948],
#        [   0,    0,    0,    0, 3198,  949, 4068, 7591],
#        [   0,    0,    0, 9576,  775, 2695, 8988,   53],
#        [   0,    0,    0, 9576,  775, 2695, 8988, 3060],
#        [   0,    0,    0, 7331, 3198, 2451, 4068, 4999],
#        [   0,    0,    0,    0, 4071, 2633, 1254, 8988]], dtype=int32)

# %%
## feature representation
dim = 10

# %%
model=Sequential()
model.add(Embedding(voc_size,dim,input_length=sent_length))
model.compile('adam','mse')

# %%
model.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_5 (Embedding)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embeded_docs)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# array([[[ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.01182947,  0.03977043, -0.0436377 ,  0.00432007,
#          -0.0182821 ,  0.02407486, -0.0445848 , -0.03149565,
#           0.0338713 , -0.02101804],
#         [ 0.02550187,  0.0344411 , -0.04635775,  0.04384348,
#           0.0135823 ,  0.01867427,  0.04867763,  0.04290941,
#          -0.03508475,  0.0331347 ],
#         [-0.03405157,  0.04876201,  0.04879005, -0.01108801,
#           0.00023419, -0.03011862, -0.03804006,  0.03419   ,
#          -0.01312299, -0.03739012],
#         [-0.02177596, -0.03913851,  0.02566822, -0.00176554,
#           0.02048932,  0.03986062, -0.02911437,  0.0376001 ,
#           0.04715035,  0.03534055]],
#
#        [[ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.01182947,  0.03977043, -0.0436377 ,  0.00432007,
#          -0.0182821 ,  0.02407486, -0.0445848 , -0.03149565,
#           0.0338713 , -0.02101804],
#         [ 0.02550187,  0.0344411 , -0.04635775,  0.04384348,
#           0.0135823 ,  0.01867427,  0.04867763,  0.04290941,
#          -0.03508475,  0.0331347 ],
#         [-0.03405157,  0.04876201,  0.04879005, -0.01108801,
#           0.00023419, -0.03011862, -0.03804006,  0.03419   ,
#          -0.01312299, -0.03739012],
#         [-0.01067968, -0.01688596, -0.04077423, -0.02710965,
#           0.00560706,  0.02102251, -0.00903757, -0.00280607,
#          -0.02769902,  0.04732201]],
#
#        [[ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.01182947,  0.03977043, -0.0436377 ,  0.00432007,
#          -0.0182821 ,  0.02407486, -0.0445848 , -0.03149565,
#           0.0338713 , -0.02101804],
#         [ 0.01640106,  0.04652203,  0.04891831, -0.03531387,
#          -0.03940129,  0.04776272,  0.04162023,  0.01979392,
#          -0.03641243, -0.01600736],
#         [-0.03405157,  0.04876201,  0.04879005, -0.01108801,
#           0.00023419, -0.03011862, -0.03804006,  0.03419   ,
#          -0.01312299, -0.03739012],
#         [ 0.03663044, -0.01215725, -0.0184641 ,  0.0463669 ,
#           0.01321718, -0.04710224,  0.02868238, -0.04924052,
#          -0.00279338, -0.0377692 ]],
#
#        [[ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03024373,  0.01293106, -0.04951987,  0.00386574,
#          -0.04672771,  0.04483792, -0.01480632,  0.01233926,
#          -0.02305522, -0.03675254],
#         [-0.00320624,  0.00703568,  0.00567684, -0.03228905,
#          -0.00021311,  0.00022718, -0.00432558,  0.01251252,
#           0.01397922, -0.00604272],
#         [-0.01495044,  0.0211505 , -0.01045731, -0.01069788,
#           0.03186445,  0.03196659,  0.00036573, -0.02881395,
#           0.04792706,  0.03608819],
#         [ 0.01064658, -0.04558044, -0.04813857,  0.02962526,
#           0.00392606, -0.01395103,  0.02278889, -0.0063043 ,
#           0.04855828, -0.02565913],
#         [ 0.0427318 ,  0.01114865, -0.04768543,  0.04592032,
#          -0.04387945, -0.00842508,  0.03350672, -0.0233041 ,
#          -0.02951684,  0.03553864]],
#
#        [[ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03024373,  0.01293106, -0.04951987,  0.00386574,
#          -0.04672771,  0.04483792, -0.01480632,  0.01233926,
#          -0.02305522, -0.03675254],
#         [-0.00320624,  0.00703568,  0.00567684, -0.03228905,
#          -0.00021311,  0.00022718, -0.00432558,  0.01251252,
#           0.01397922, -0.00604272],
#         [-0.01495044,  0.0211505 , -0.01045731, -0.01069788,
#           0.03186445,  0.03196659,  0.00036573, -0.02881395,
#           0.04792706,  0.03608819],
#         [ 0.01064658, -0.04558044, -0.04813857,  0.02962526,
#           0.00392606, -0.01395103,  0.02278889, -0.0063043 ,
#           0.04855828, -0.02565913],
#         [ 0.0255066 , -0.0445932 ,  0.02068834, -0.04047741,
#           0.03319191, -0.01876727,  0.0499077 , -0.0182742 ,
#          -0.02517775, -0.00162351]],
#
#        [[ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [-0.04852101,  0.03790914,  0.04355654,  0.032586  ,
#           0.03497886, -0.03365871,  0.04912014,  0.02939193,
#           0.04148436, -0.00852503],
#         [ 0.01182947,  0.03977043, -0.0436377 ,  0.00432007,
#          -0.0182821 ,  0.02407486, -0.0445848 , -0.03149565,
#           0.0338713 , -0.02101804],
#         [ 0.03110439,  0.02441582, -0.0430752 , -0.01666397,
#          -0.04357317,  0.03738134,  0.04072073,  0.03113792,
#           0.00625572, -0.02551712],
#         [-0.03405157,  0.04876201,  0.04879005, -0.01108801,
#           0.00023419, -0.03011862, -0.03804006,  0.03419   ,
#          -0.01312299, -0.03739012],
#         [-0.04974979, -0.01553972, -0.04548359, -0.0426961 ,
#          -0.00619279,  0.03607874,  0.04821651, -0.01764464,
#          -0.04719893, -0.03870171]],
#
#        [[ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [-0.03769789, -0.02055737,  0.02440628,  0.01329184,
#           0.01413189,  0.01913161, -0.04603107, -0.00211722,
#           0.00052477,  0.03681562],
#         [-0.04869775,  0.00109922,  0.00036122, -0.00609343,
#          -0.02037886, -0.02312642,  0.00471778,  0.02046777,
#          -0.04989476,  0.00490544],
#         [ 0.02740714,  0.01915227, -0.01607699,  0.04461003,
#           0.03206393, -0.02116838, -0.02451913, -0.04550281,
#          -0.00600419,  0.02194946],
#         [ 0.01064658, -0.04558044, -0.04813857,  0.02962526,
#           0.00392606, -0.01395103,  0.02278889, -0.0063043 ,
#           0.04855828, -0.02565913]]], dtype=float32)

# %%
embeded_docs[0]
# Out:
# array([   0,    0,    0,    0, 3198, 2926, 4068, 1627], dtype=int32)

# %%
model.predict(embeded_docs[0].reshape(1, -1))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# array([[[ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.03224931, -0.01905992, -0.03387039,  0.04124869,
#          -0.00282266,  0.01936323,  0.03963769, -0.0442106 ,
#          -0.00732462, -0.0343776 ],
#         [ 0.01182947,  0.03977043, -0.0436377 ,  0.00432007,
#          -0.0182821 ,  0.02407486, -0.0445848 , -0.03149565,
#           0.0338713 , -0.02101804],
#         [ 0.02550187,  0.0344411 , -0.04635775,  0.04384348,
#           0.0135823 ,  0.01867427,  0.04867763,  0.04290941,
#          -0.03508475,  0.0331347 ],
#         [-0.03405157,  0.04876201,  0.04879005, -0.01108801,
#           0.00023419, -0.03011862, -0.03804006,  0.03419   ,
#          -0.01312299, -0.03739012],
#         [-0.02177596, -0.03913851,  0.02566822, -0.00176554,
#           0.02048932,  0.03986062, -0.02911437,  0.0376001 ,
#           0.04715035,  0.03534055]]], dtype=float32)
